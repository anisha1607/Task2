# %%
import pandas as pd
df= pd.read_csv("Health_systems.csv")

# %%
df1=pd.read_csv("Health_systems.csv")

# %%
df.dropna(axis=1,inplace=True)
df
# Out:
#               World_Bank_Name
# 0                 Afghanistan
# 1                     Albania
# 2                     Algeria
# 3                     Andorra
# 4                      Angola
# 5         Antigua and Barbuda
# 6                   Argentina
# 7                     Armenia
# 8                   Australia
# 9                     Austria
# 10                 Azerbaijan
# 11               Bahamas, The
# 12                    Bahrain
# 13                 Bangladesh
# 14                   Barbados
# 15                    Belarus
# 16                    Belgium
# 17                     Belize
# 18                      Benin
# 19                     Bhutan
# 20                    Bolivia
# 21     Bosnia and Herzegovina
# 22                   Botswana
# 23                     Brazil
# 24          Brunei Darussalam
# 25                   Bulgaria
# 26               Burkina Faso
# 27                    Burundi
# 28                 Cabo Verde
# 29                   Cambodia
# ...

# %%
df1.describe()
# Out:
#        Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# count               186.000000                  186.000000
# mean                  6.715054                   52.915054
# std                   2.976537                   21.957736
# min                   1.700000                    5.100000
# 25%                   4.500000                   36.825000
# 50%                   6.200000                   55.850000
# 75%                   8.375000                   70.600000
# max                  23.300000                   96.000000
#
#        Health_exp_out_of_pocket_pct_2016  Health_exp_per_capita_USD_2016  \
# count                         186.000000                      186.000000
# mean                           32.661828                     1037.004839
# std                            19.572777                     1712.592621
# min                             0.100000                       16.400000
# ...

# %%
new_df=df1.fillna({
    'Health_exp_pct_GDP_2016':6.715054,
    'Health_exp_public_pct_2016':52.915054,
    'Health_exp_out_of_pocket_pct_2016':32.661828,
    'Health_exp_per_capita_USD_2016': 1037.004839,
    'per_capita_exp_PPP_2016':1412.466667,
    'External_health_exp_pct_2016':9.116766,
    'Physicians_per_1000_2009-18':1.723280,
    'Nurse_midwife_per_1000_2009-18':4.139153,
    'Specialist_surgical_per_1000_2008-18':37.937143,
    'Completeness_of_birth_reg_2009-18':84.202454,
    'Completeness_of_death_reg_2008-16':89.309346
})
new_df
# Out:
#              Country_Region  Province_State           World_Bank_Name  \
# 0               Afghanistan             NaN               Afghanistan
# 1                   Albania             NaN                   Albania
# 2                   Algeria             NaN                   Algeria
# 3                   Andorra             NaN                   Andorra
# 4                    Angola             NaN                    Angola
# 5       Antigua and Barbuda             NaN       Antigua and Barbuda
# 6                 Argentina             NaN                 Argentina
# 7                   Armenia             NaN                   Armenia
# 8                 Australia             NaN                 Australia
# 9                   Austria             NaN                   Austria
# 10               Azerbaijan             NaN                Azerbaijan
# 11                  Bahamas             NaN              Bahamas, The
# ...
